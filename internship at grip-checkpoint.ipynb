# %% [markdown]
# # YASHA M BHAT
#
# ## Data science and Business Analytics
#
# ## TASK - 2
#
# ### Prediction using unsupervised ML(Level - Beginner)
# ### From the given 'Iris' dataset, optimum number of clusters areb represented visually.
# ### Use R or Python to perform this task.
# ### Dataset: https://bit.ly/3kXTdox
#
# ## UNSUPERVISED LEARNING:
#
# ### Unsupervised learning refers to the use of artificial intelligence (AI) algorithms to identify patterns in data sets containing data points that are neither classified nor labeled. In other words, unsupervised learning allows the system to identify patterns within data sets on its own.
#
# ## K-Means Clustering:
#
# ### K-means clustering is a type of unsupervised learning, which is used when you have unlabeled data (i.e., data without defined categories or groups). The goal of this algorithm is to find groups in the data, with the number of groups represented by the variable K. Data points are clustered based on feature similarity.

# %% [markdown]
# ## Installing matplotlib

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Installing pandas

# %%
# !pip install pandas

# %% [markdown]
# ## Insatlling seaborn

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Download the dataset

# %%
data = pd.read_csv(r'C:\Users\sai\Downloads\Iris.csv')
print('data downloaded')
print('shape',data.shape)
data.head(10)
# Out:
# data downloaded
# shape (150, 6)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# ## Displaying the basic information about the given dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Verifying if any values are missed

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## Display the column names

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ## Target variable, counting the data

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Describing data using describe() method to calculate the basic values of the species

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## BOX PLOT

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=data).set_title('Box plot')
# Out:
# Text(0.5, 1.0, 'Box plot')

# %%
sns.boxplot(x='Species',y='PetalWidthCm',data=data).set_title('Box plot')
# Out:
# Text(0.5, 1.0, 'Box plot')

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=data,size=5)
# Out:
# C:\Users\sai\.conda\envs\OpenCV\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## VIOLIN PLOT

# %%
sns.violinplot(x='Species',y='SepalLengthCm',data=data,size=6).set_title('violin plot')
# Out:
# Text(0.5, 1.0, 'violin plot')

# %%
sns.violinplot(x='Species',y='SepalWidthCm',data=data,size=6).set_title('violin plot')
# Out:
# Text(0.5, 1.0, 'violin plot')

# %% [markdown]
# ## HEAT MAP

# %%
sns.heatmap(data.corr(),).set_title('heat map')
# Out:
# Text(0.5, 1.0, 'heat map')

# %% [markdown]
# ## HIST PLOT to check column alignment and distribution

# %%
data.hist(figsize=(10,6))
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'SepalLengthCm'}>],
#        [<AxesSubplot:title={'center':'SepalWidthCm'}>,
#         <AxesSubplot:title={'center':'PetalLengthCm'}>],
#        [<AxesSubplot:title={'center':'PetalWidthCm'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.pairplot(data=data,kind='scatter')

# %%
sns.pairplot(data=data,hue='Species')

# %% [markdown]
# ### The above plot shows the relationship between columns and types of species

# %% [markdown]
# ## Install scikit-learn

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.cluster import KMeans
LIST=[]
x = data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm',]].to_numpy()
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',
                   max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    LIST.append(kmeans.inertia_)
# Out:
# C:\Users\sai\.conda\envs\OpenCV\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
from sklearn.cluster import KMeans
LIST=[]
x = data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm',]].to_numpy()
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',
                   max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    LIST.append(kmeans.inertia_)
# Out:
# C:\Users\sai\.conda\envs\OpenCV\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %% [markdown]
# ### The graph has an optimum cluster at the elbow curve

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
               max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1],
           s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1],
           s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
           s = 100, c = 'green', label = 'Iris-virginica')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
           s = 100, c = 'yellow', label = 'Centroids')
plt.legend()
